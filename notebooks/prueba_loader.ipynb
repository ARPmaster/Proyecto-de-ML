# %%
import os
import sys

# Ir a la raíz del proyecto
os.chdir("/home/king/Documentos/Proyecto de ml")
sys.path.append(".")

print("Directorio actual:", os.getcwd())

from src.loader import Loader

loader = Loader()
df_anime = loader.cargar("anime")
df_anime.head()
# Out:
# Directorio actual: /home/king

# %%
print("Columnas:", df_anime.columns.tolist())
print("Filas:", len(df_anime))
print("Origen:", df_anime["origen"].unique())

# %%
df_series = loader.cargar("series_data")
df_series.head()

# %%
df_total = loader.cargar_todos(["anime", "series_data"])

print("Total filas:", len(df_total))
print(df_total["origen"].value_counts())
